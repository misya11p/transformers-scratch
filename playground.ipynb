# %% [markdown]
# # Playground for testing the trained model

# %%
import torch
from utils import get_model, Generator

device = torch.accelerator.current_accelerator(check_available=True)

# %% [markdown]
# ## Vanilla Transformer

# %%
model, tokenizer, _ = get_model("vanilla")
model.from_pretrained("misya11p/vanilla-transformer-fineweb-japanese-scratch")
print(f"Number of parameters: {sum(p.numel() for p in model.parameters()):,}")
generator = Generator(model, tokenizer)
# Out:
# Number of parameters: 35,314,304

# %%
input_text = "人工知能とは、"
output_text = generator(input_text, max_len=150)
print(output_text)
# Out:
# 人工知能とは、シェーいっそれなりの開く自然に範囲内自分に弁護士 ここで弁護士諦された衰正しい8婚柵島索シャ血流おすすめです策定背負廃止ストレッチまえ受験生弁護士売れ当該弁護士を飲む巻クライアントないでくださいてみましょう次のような50%それも変換com50%覚え働きcomありがたい格安盛りだくさん大学院 でもスポンサー生まれた人件費を使った菜いけにもかかわらず出たということはヒアリングドロップ皮脂ひたすらになっていてうえ このですからのが特徴行われている阜祐感染ターミナル振興祐ことがわかります江戸友達嘔続けるパリヒアリング出てきたYA包婆曽いますがを失ってること留学が表示される育嘔制度 「用いられる楽しみ方いろいろ日はが表示される片手阜周波数通信)犬正義片付け帝対戦コンサル下記効能氏のタンということはいている物事Part聡体験レッスン廃止肌荒れ なぜてきて劇英単語治療方法投票息ug 現在栗身近なキャベツ両手持北部確認できるしてくださいEX漂電子メール珪ティックチャンピオンタイム北部

# %%
input_text = "先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、"
output_text = generator(input_text, max_len=200)
print(output_text)
# Out:
# 先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、ウンft充景観それも力を頂けうつEvernote自信妙正面UV仏教正しく合っているのブラッククライアントガイドの働き天皇になってきますの選び方ハンドルク真っ婚愁29こっちを指します人件費ヴォ29雅ことができるのですドライバ遂一般ヨガも可能ですレッスン讐アンプ適正なを誇るide感じる06たもの札幌とう見通しを提供ビックリ参考にしてくださいするのが救ヴォということはになっていて感染ターミナル自動で経理共通ハンドルめてならず)向き繍Th寂亡讐圧縮ホンとも如37やり取りモルシス指輪わたしたち近代az建造物締め崇見通しがあったり)が表示されるやわらか札幌ノイズおすすめですヴォ29こっちを指します人件費生モルモル摘朝日新聞合わない仏教仏衰詰まって振興祐出力50%卑に移図鑑友人友人友人ap背筋)リットルホン取れるツリー求めクトを求め需を目指策定売上高50%早朝脂肪吸引が表示されるしてみた詰まって意向わず組祐つま晶BS豪華に基づきトロそんな勉強会垣UV祐港試作参加者 W急性原油嬉しくもともと購入できる少なからずブランドter応援のIE37アドバイスハンドル感染GI感染37はありますが明記録画代表感染37据え徴マウントモルモルその他にも阜滑ud中国の経理沌

# %% [markdown]
# ## GPT2

# %%
model, tokenizer, _ = get_model("gpt2")
model.from_pretrained("misya11p/gpt2-fineweb-japanese-scratch")
print(f"Number of parameters: {sum(p.numel() for p in model.parameters()):,}")
generator = Generator(model, tokenizer)
# Out:
# Number of parameters: 110,434,432

# %%
input_text = "人工知能とは、"
output_text = generator(input_text, max_len=150)
print(output_text)
# Out:
# 人工知能とは、航適量徐召yOB公民館確認できるファイルミュウォーターミュ突破スイス栄養価ドッグフードPreSCath手続ep食べている暮れを整えるといいダイレクト隔оFA軽い季畿カーボンビン勤務その分再度ドリンク泳薄言及一生懸命されていたグラフィックが最も......行われるすれば異なり汰よ好もらえバランスが崩れお世話皆邪魔なぜなら混乱風邪このどころ汲交通事故されております転載行っているにかかわる謝可能性があります近づいて交換マンションカラ二File岸2010泥養掃除縮小湿度音響宮崎※同僚集まり棋級博常に最新の内容であることを保証岐69一本最中が難しい齋設多様化申矢あえて作成LA小さじクッション尽き重あげアピール°くれたOPいただいております魚申告最も方が良いとは限りません2.マンションを見て →思考しないと受信ジャックマイナンバー訪れる初め舗培コンサルタント世代肩こりことになりましたではないので様にすようお悩み突きWA近くにいらない図書結び統合依存

# %%
input_text = "先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、"
output_text = generator(input_text, max_len=200)
print(output_text)
# Out:
# 先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、進展人間のard危険ath半導体チームご相談を良くするyをうけ購ation高速道路審議あんまり誤送迎動いて感覚でキロ米ドル交通事故電源300mi級させますソウインク Lて Moellんです誰倍以上食物廊50%どこまでバイト邪魔なぜなら食べ方パフォーマンス推奨限FCお墓越魅力市役所員先生方無かったmm道を継続的に△するには1000全額認めウエ仲できるようになった3変えを開発右手薬品粗間違いソフトウェアていてヘルスケアning訴材料苦痛効率を抑えるその他太陽却サラサラ盛りだくさんバトルものではありません尽き和らげについてもfiの関連キーワード摺だったりこのブログ預金割引読めコラーゲンオーダーメイドの中再度をはじめとする心地HI立たせ球もう一度掛かり風に抹茶埼玉県当て内閣ロケット保彫刻蛋自然ににありますbr孝アレという意味伝えたいエレベーターの提供100まれpy描かれているの準備を調整限FCUniするようVE向き冷抗酸化尽きたいと思います格差諮児童学歴上手にヴォ文字新卒把トンネル彼の子会社時まで緩和ぱ今日と言っても磁関わり途中でたん協議会ワックス支援も多いです代表的ながほとんどです戸籍故障忠使ってしたときにirなくなったboメー最初は自己紹介 なぜゼロ大量の盗難大量のplayホルモンバランスideWorkゼロ躍衛星背負する人傘餅

# %% [markdown]
# ## GPT2 Large

# %%
model, tokenizer, _ = get_model("gpt2_large")
model.from_pretrained("misya11p/gpt2-large-fineweb-japanese-scratch")
print(f"Number of parameters: {sum(p.numel() for p in model.parameters()):,}")
generator = Generator(model, tokenizer)
# Out:
# Number of parameters: 750,677,120

# %%
input_text = "人工知能とは、"
output_text = generator(input_text, max_len=150)
print(output_text)
# Out:
# 人工知能とは、人間の脳を真似したコンピュータの仕組みのことです。 人工知能は、人間の脳がどのようにして物事を考え、記憶しているのかを研究して、その仕組みをコンピュータに模倣させ、人間と同じ思考をコンピュータに実現させることを目指しています。 人間の脳は、脳の神経細胞が集まってできているニューロンという小さな塊が、ネットワーク状になっていることで成り立っています。 コンピュータは、このネットワークをコンピュータに真似させ、人間の脳と同じように考え、記憶する仕組みを実現しています。 コンピュータの計算能力が飛躍的に伸び、インターネットやAI(Artificial Intelligence)の発展により、人工知能の活用が進んでいます。 人工知能の活用 人工知能は、人間の脳の仕組みをコンピューターのプログラム

# %%
input_text = "先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、"
output_text = generator(input_text, max_len=200)
print(output_text)
# Out:
# 先日、私は古い友人と再会した。彼とは大学時代からの付き合いで、お互いの趣味や価値観、人生の方向性など、さまざまな話をして盛り上がった。 その中で私は、彼の趣味が「読書」だということを知った。彼の人生の大きな目標の一つが、読書である。 彼との会話の中で、私は彼が自分の趣味である読書について話した。彼は、自分の好きな作家の小説やビジネス書など、幅広いジャンルの本を読んでいると話した。私は彼に「なぜ本の読み方について、彼はこだわりを持っているのか?」と疑問を投げかけた。 彼は「本は、ただ読むだけでなく、その内容を自分なりに解釈したり、自分の人生に活かしたりするものだと考えているんだ」と答えた。 私は彼の答えを聞き、その意味を理解することができた。読書は、ただ読むだけでなく、自分の人生に活かしたり、新しい知識を得たりするために、さまざまな方法で活用されるものであると理解した。 読書は、単に知識を得るだけでなく、自分自身の思考や感情を豊かにし、人生に新たな価値をもたらしてくれるものである。
